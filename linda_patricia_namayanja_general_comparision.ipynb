# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score



# Accuracy scores of the algorithms (replace these values with your actual scores)
accuracy_scores = {
    "Logistic Regression": 0.85,
    "KNN": 0.82,
    "SVM": 0.89,
    "Naive Bayes": 0.78,
    "Decision Tree": 0.87,
    "Random Forest": 0.91,
    "Confusion Matrix": 0.82
}

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(accuracy_scores.keys(), accuracy_scores.values(), color='skyblue')
plt.xlabel('Algorithms')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores of Different Machine Learning Models')
plt.ylim(0, 1.0)  # Set the y-axis limits to 0 and 1 for better visualization of accuracy scores
plt.xticks(rotation=45)

# Display the accuracy scores on top of the bars
for i, v in enumerate(accuracy_scores.values()):
    plt.text(i, v + 0.01, str(v), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
#decision trees with the heart disease dataset
# DECISION TREE MODELS

hrt=pd.read_csv("heart_disease.csv")
hrt.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
